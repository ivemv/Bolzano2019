# %%
import obspy
from obspy import *
from obspy import read, UTCDateTime, Stream, read_inventory
from scipy import signal
from scipy.signal import welch
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline
#%matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/marv/anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['__version__']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ### BB:100sps
# ### RSB:100sps
# ### CUBE:200sps

# %%
inv_r = read_inventory("inv.xml") #Archivo de respuesta RESCO
inv_rb = read_inventory("R9C82.xml") #Archivo de respuesta CGEO-RSPBerry
inv_c1 = read_inventory("MNGR2-200.xml") #Archivo de respuesta CUBE 200sps
#inv_c2 = read_inventory("cube_100.xml") #Archivo de respuesta CUBE 100sps

# %%
st = inv_r.networks[0][0]

# %%
c = st[3]

# %%
c
# Out:
# Channel 'BDF', Location ''
# 	Time range: 2018-01-01T00:00:00.000000Z - --
# 	Latitude: 19.47, Longitude: -103.62, Elevation: 2111.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (None)
# 	Response information available

# %%
ci = st[0]

# %%
ce = st[1]

# %%
cn = st[2]

# %%
c.response
# Out:
# Channel Response
# 	From M/S (Velocity in Meters Per Second) to COUNTS (None)
# 	Overall Sensitivity: 400000 defined at 1.000 Hz
# 	5 stages:
# 		Stage 1: PolesZerosResponseStage from M/S to V, gain: 1
# 		Stage 2: CoefficientsTypeResponseStage from V to COUNTS, gain: 400000
# 		Stage 3: FIRResponseStage from COUNTS to COUNTS, gain: 1
# 		Stage 4: FIRResponseStage from COUNTS to COUNTS, gain: 1
# 		Stage 5: FIRResponseStage from COUNTS to COUNTS, gain: 1

# %%
s = 5.24161E+10 #sensitividad cube

# %%
#Cuentas*(3.125e-8)=m/s factor de conversión geófono en CGEO
geo = 3.125e-8

# %%
r2 = read("UC_MNGR_2018070921.mseed");
#cm2 = read("AM")
#cu3 = read("UC.M")

# %%
r2.merge(method=0,fill_value=0)
# Out:
# 4 Trace(s) in Stream:
# UC.MNGR..BDF | 2018-07-09T20:45:00.000000Z - 2018-07-09T22:30:00.000000Z | 100.0 Hz, 630001 samples
# UC.MNGR..HHE | 2018-07-09T20:45:00.000000Z - 2018-07-09T22:30:00.000000Z | 100.0 Hz, 630001 samples
# UC.MNGR..HHN | 2018-07-09T20:45:00.000000Z - 2018-07-09T22:30:00.000000Z | 100.0 Hz, 630001 samples
# UC.MNGR..HHZ | 2018-07-09T20:45:00.000000Z - 2018-07-09T22:30:00.000000Z | 100.0 Hz, 630001 samples

# %%
r2.remove_sensitivity(inv_r)
# Out:
# 4 Trace(s) in Stream:
# UC.MNGR..BDF | 2018-07-09T20:45:00.000000Z - 2018-07-09T22:30:00.000000Z | 100.0 Hz, 630001 samples
# UC.MNGR..HHE | 2018-07-09T20:45:00.000000Z - 2018-07-09T22:30:00.000000Z | 100.0 Hz, 630001 samples
# UC.MNGR..HHN | 2018-07-09T20:45:00.000000Z - 2018-07-09T22:30:00.000000Z | 100.0 Hz, 630001 samples
# UC.MNGR..HHZ | 2018-07-09T20:45:00.000000Z - 2018-07-09T22:30:00.000000Z | 100.0 Hz, 630001 samples

# %%
r2.plot(equal_scale=False)

# %%
in3 = r3[3]

# %%
in3.write("in_prue.mseed",format="MSEED")

# %%
r3 = read("UC_MNGR_2018071521.mseed");
cm3 = read("AM.R9C82.2018071521c.mseed");
cu3 = read("UC_MNG2_20180715.mseed");
in3 = read("in_prue.mseed")

# %%
r3.filter("highpass",freq=1)
cm3.filter("highpass",freq=1)
cu3.filter("highpass",freq=1)
in3.filter("highpass",freq=1)
# Out:
# 1 Trace(s) in Stream:
# UC.MNGR..BDF | 2018-07-15T21:30:00.000000Z - 2018-07-15T23:30:00.000000Z | 100.0 Hz, 720001 samples

# %%
a3 = r3[0];
b3 = cm3[0];
c3 = cu3[2];
i3 = in3[0];

# %%
r3.remove_sensitivity(inv_r);
cm3.remove_sensitivity(inv_rb);

# %%
c3.data = c3.data*(1/5.24161E10)

# %%
i3.data = i3.data*(1/12100)

# %%
a3.detrend();
b3.detrend();
c3.detrend();
in3.detrend();
# Out:
# /home/marv/anaconda3/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):

# %%
r5 = read("UC_MNGR_2018072822.mseed");
cm5 = read("AM.R9C82.2018072822.mseed");
cu5 = read("UC_MNG2_20180728.mseed");
in5 = read("inf5.mseed");

# %%
r5.filter("highpass",freq=1)
cm5.filter("highpass",freq=1)
cu5.filter("highpass",freq=1)
in5.filter("highpass",freq=1)
# Out:
# 1 Trace(s) in Stream:
# UC.MNGR..BDF | 2018-07-28T22:30:00.000000Z - 2018-07-28T23:59:59.990000Z | 100.0 Hz, 540000 samples

# %%
a5 = r5[0];
b5 = cm5[0];
c5 = cu5[2];
i5 = in5[0];

# %%
r5.remove_sensitivity(inv_r);
cm5.remove_sensitivity(inv_rb);

# %%
c5.data = c5.data*(1/5.24161E+10)

# %%
i5.data = i5.data*(1/12100)

# %%
a5.detrend();
b5.detrend();
c5.detrend();
i5.detrend();
# Out:
# /home/marv/anaconda3/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):

# %%
r7 = read("UC_MNGR_2018081619.mseed");
cm7 = read("AM.R9C82.2018081619.mseed");
cu7 = read("UC_MNG2_20180816.mseed");
in7 = read("infra7.mseed");

# %%
r7.filter("highpass",freq=1)
cm7.filter("highpass",freq=1)
cu7.filter("highpass",freq=1)
in7.filter("highpass",freq=1)
# Out:
# 1 Trace(s) in Stream:
# UC.MNGR..BDF | 2018-08-16T19:00:00.000000Z - 2018-08-16T22:00:00.000000Z | 100.0 Hz, 1080001 samples

# %%
a7 = r7[0];
b7 = cm7[0];
c7 = cu7[2];
i7 = in7[0];

# %%
r7.remove_sensitivity(inv_r);
cm7.remove_sensitivity(inv_rb);

# %%
c7.data = c7.data*(1/5.24161E+10)

# %%
i7.data = i7.data*(1/12100)

# %%
a7.detrend();
b7.detrend();
c7.detrend();
i7.detrend();
# Out:
# /home/marv/anaconda3/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):

# %%
r8 = read("UC_MNGR_2018081722.mseed");
c8 = read("AM.R9C82.2018081722.mseed");
cu8 = read("UC_MNG2_20180817.mseed");
in8 = read("inf8.mseed");

# %%
a8 = r8[0];
b8 = c8[0];
c8 = cu8[2];
i8 = in8[0];

# %%
c8.data = c8.data*(1/5.24161E+10)

# %%
i8.data = i8.data*(1/12100)

# %%
a8.detrend();
b8.detrend();
c8.detrend();
i8.detrend();
# Out:
# /home/marv/anaconda3/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):

# %%
r8.remove_sensitivity(inv_r);
c8.remove_sensitivity(inv_rb);

# %%
an8 = r8[1];

an8.detrend();

# %%
r9 = read("UC_MNGR_20180818-.mseed");
c9 = read("AM.R9C82.2018081823.mseed");
cu9 = read("UC_MNG2_20180818.mseed");

# %%
r9.remove_sensitivity(inv_r);
c9.remove_sensitivity(inv_rb);

# %%
a9 = r9[3];
b9 = c9[0];
c9 = cu9[2];
i9 = r9[0];

c9.data = c9.data*(1/5.24161E+10)

a9.detrend();
b9.detrend();
c9.detrend();
i9.detrend();

# %%
r10 = read("UC_MNGR_2018082223_.mseed");
c10 = read("AM.R9C82.2018082223.mseed");
cu10 = read("UC_MNG2_20180822.mseed");

# %%
r10.remove_sensitivity(inv_r);
c10.remove_sensitivity(inv_rb);

# %%
a10 = r10[3];
b10 = c10[0];
c10 = cu10[2];
i10 = r10[0];

c10.data = c10.data*(1/5.24161E+10)

a10.detrend();
b10.detrend();
c10.detrend();
i10.detrend();

# %%
r11 = read("UC_MNGR_2018082322.mseed");
c11 = read("AM.R9C82.2018082322.mseed");
cu11 = read("UC_MNG2_20180823.mseed");

# %%
r11.remove_sensitivity(inv_r);
c11.remove_sensitivity(inv_rb);

# %%
a11 = r11[0];
b11 = c11[0];
c11 = cu11[2];
i11 = r11[3];

c11.data = c11.data*(1/5.24161E+10)

a11.detrend();
b11.detrend();
c11.detrend();
i11.detrend();

# %%
r17 = read("UC_MNGR_2018100623_.mseed");
cm17 = read("AM.R9C82.2018100623.mseed");
cu17 = read("UC_MNG2_20181006_2.mseed");
in17 = read("inf17.mseed");

# %%
r17.filter("highpass",freq=1)
cm17.filter("highpass",freq=1)
cu17.filter("highpass",freq=1)
in17.filter("highpass",freq=1)
# Out:
# 1 Trace(s) in Stream:
# UC.MNGR..BDF | 2018-10-06T23:30:00.000000Z - 2018-10-07T01:30:00.000000Z | 100.0 Hz, 720001 samples

# %%
a17 = r17[3];
b17 = cm17[0];
c17 = cu17[2];
i17 = in17[0];

# %%
c17.data = c17.data*(1/5.24161E+10)

# %%
i17.data = i17.data*(1/12100)

# %%
r17.remove_sensitivity(inv_r);
cm17.remove_sensitivity(inv_rb);

# %%
a17.detrend();
b17.detrend();
c17.detrend();
i17.detrend();

# %%
r20 = read("UC_MNGR_2018101923_.mseed");
c20 = read("UC.LUCIA.2018101923.mseed");
cu20 = read("UC_MNG2_20181019.mseed");

# %%
r20.remove_sensitivity(inv_r);

# %%
a20 = r20[3];
b20 = c20[0];
c20 = cu20[2];
i20 = r20[0];

b20.data = b20.data*3.125e-8
c20.data = c20.data*(1/5.24161E+10)

a20.detrend();
b20.detrend();
c20.detrend();
i20.detrend();

# %%
r21 = read("UC_MNGR_2018102822.mseed")
c21 = read("UC.LUCIA.2018102822.mseed")
cu21 = read("UC_MNG2_20181028.mseed")

# %%
r21.remove_sensitivity(inv_r);

# %%
a21 = r21[0];
b21 = c21[0];
c21 = cu21[2];
i21 = r21[3];

b21.data = b21.data*3.125e-8
c21.data = c21.data*(1/5.24161E+10)

a21.detrend();
b21.detrend();
c21.detrend();
i21.detrend();

# %%
#PDS's

# %%
fi2, ami2 = signal.welch(i,fs=100,nperseg=3600,noverlap=50)
f2, am2 = signal.welch(z,fs=100,nperseg=3600,noverlap=50)

# %%
fi, ami = signal.welch(i3,fs=100,nperseg=3600,noverlap=50)
f3, am3 = signal.welch(a3,fs=100,nperseg=3600,noverlap=50)
fg, amg =  signal.welch(b3,fs=100,nperseg=3600,noverlap=50)
fc, amc = signal.welch(c3,fs=200,nperseg=3600,noverlap=50)

# %%
fi5 , ami5 = signal.welch(i5,fs=100,nperseg=3600,noverlap=50)
f5 , am5 = signal.welch(a5,fs=100,nperseg=3600,noverlap=50)
fg5 , amg5 = signal.welch(b5,fs=100,nperseg=3600,noverlap=50)
fc5 , amc5 = signal.welch(c5,fs=100,nperseg=3600,noverlap=50)

# %%
fi7 , ami7 = signal.welch(i7,fs=100,nperseg=3600,noverlap=50)
f7 , am7 = signal.welch(a7,fs=100,nperseg=3600,noverlap=50)
fg7 , amg7 = signal.welch(b7,fs=100,nperseg=3600,noverlap=50)
fc7 , amc7 = signal.welch(c7,fs=100,nperseg=3600,noverlap=50)

# %%
fi8 , ami8 = signal.welch(i8,fs=100,nperseg=3600,noverlap=50)
f8 , am8 = signal.welch(a8,fs=100,nperseg=3600,noverlap=50)
fg8 , amg8 = signal.welch(b8,fs=100,nperseg=3600,noverlap=50)
fc8 , amc8 = signal.welch(c8,fs=100,nperseg=3600,noverlap=50)

# %%
fi9 , ami9 = signal.welch(i9,fs=100,nperseg=3600,noverlap=50)
f9 , am9 = signal.welch(a9,fs=100,nperseg=3600,noverlap=50)
fg9 , amg9 = signal.welch(b9,fs=100,nperseg=3600,noverlap=50)
fc9 , amc9 = signal.welch(c9,fs=100,nperseg=3600,noverlap=50)

# %%
fi10 , ami10 = signal.welch(i10,fs=100,nperseg=3600,noverlap=50)
f10 , am10 = signal.welch(a10,fs=100,nperseg=3600,noverlap=50)
fg10 , amg10 = signal.welch(b10,fs=100,nperseg=3600,noverlap=50)
fc10 , amc10 = signal.welch(c10,fs=100,nperseg=3600,noverlap=50)

# %%
fi11 , ami11 = signal.welch(i11,fs=100,nperseg=3600,noverlap=50)
f11 , am11 = signal.welch(a11,fs=100,nperseg=3600,noverlap=50)
fg11 , amg11 = signal.welch(b11,fs=100,nperseg=3600,noverlap=50)
fc11 , amc11 = signal.welch(c11,fs=100,nperseg=3600,noverlap=50)

# %%
fi17 , ami17 = signal.welch(i17,fs=100,nperseg=3600,noverlap=50)
f17 , am17 = signal.welch(a17,fs=100,nperseg=3600,noverlap=50)
fg17 , amg17 = signal.welch(b17,fs=100,nperseg=3600,noverlap=50)
fc17 , amc17 = signal.welch(c17,fs=100,nperseg=3600,noverlap=50)

# %%
fi19, ami19 = signal.welch(i19,fs=100,nperseg=3600,noverlap=50)
f19, am19 = signal.welch(z19,fs=100,nperseg=3600,noverlap=50)

# %%
fi20 , ami20 = signal.welch(i20,fs=100,nperseg=3600,noverlap=50)
f20 , am20 = signal.welch(a20,fs=100,nperseg=3600,noverlap=50)
fg20 , amg20 = signal.welch(b20,fs=100,nperseg=3600,noverlap=50)
fc20 , amc20 = signal.welch(c20,fs=100,nperseg=3600,noverlap=50)

# %%
fi21 , ami21 = signal.welch(i21,fs=100,nperseg=3600,noverlap=50)
f21 , am21 = signal.welch(a21,fs=100,nperseg=3600,noverlap=50)
fg21 , amg21 = signal.welch(b21,fs=100,nperseg=3600,noverlap=50)
fc21 , amc21 = signal.welch(c21,fs=100,nperseg=3600,noverlap=50)

# %%
# PSD's de la componente N

# %%
plt.rcParams['figure.figsize'] = 30, 25
fig = plt.figure()
#plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.08)
plt.suptitle('06/10/18',fontsize=22,fontweight='bold', y=0.9)


ax1 = fig.add_subplot(4,2,1)
plt.plot(i17.times(),i17.data,'c',label="Infra-RESCO")
plt.xlim(0,7201)
plt.xticks(fontsize=17)
plt.ylabel("Pa",fontsize=17)
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax2 = fig.add_subplot(4,2,2)
plt.plot(fi17,ami17,'c',label="Fmx=13.28 Hz")
plt.xlim(1,max(fi17))
plt.xticks(fontsize=18)
#plt.xticks(np.arange(1,50,3))
#plt.ylim(0,0.000006)
plt.yticks(fontsize=15)
plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax3 = fig.add_subplot(4,2,3)
plt.plot(a17.times(),a17.data*1000,'r',label="RESCO")
plt.xlim(0,7201)
plt.xticks(fontsize=17)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.7,0.7)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax4 = fig.add_subplot(4,2,4)
plt.plot(f17,am17,'r',label="Fmx=11Hz")
plt.xlim(1,max(f17))
plt.xticks(fontsize=18)
plt.yticks(fontsize=15)
#plt.yticks(format='sci')
#plt.ylim(0,0.45E6)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax5 = fig.add_subplot(4,2,5)
plt.plot(b17.times(),b17.data*1000,'b',label="CGEO")
plt.xlim(0,7201)
plt.xticks(fontsize=17)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.7,0.7)
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax6 = fig.add_subplot(4,2,6)
plt.plot(fg17,amg17,'b',label="Fmx=16.5")
plt.xlim(1,max(fg17))
plt.xticks(fontsize=18)
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax7 = fig.add_subplot(4,2,7)
plt.plot(c17.times(),c17.data*1000,'g',label="CUBE")
plt.xlim(0,7201)
plt.xticks(fontsize=17)
plt.xlabel("Time [s]",fontsize=17)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.7,0.7)
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax8 = fig.add_subplot(4,2,8)
plt.plot(fc17,amc17,'g',label="Fmx=13.5")
#plt.axvline(x=50, linewidth=4,label="-50Hz")
plt.xlabel('Frequency [Hz]',fontsize=17)
plt.xticks(fontsize=18)
plt.xlim(1,max(f17))
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

plt.savefig("061018_e.png",dpi=300)

# %%
#prue = moving_average(ifr5,36000);

# %%
max(i3.data)
# Out:
# 6.624910515251158

# %%
plt.rcParams['figure.figsize'] = 30, 25
fig = plt.figure()
#plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.08)
plt.suptitle('15/07/18',fontsize=22,fontweight='bold', y=0.9)


ax1 = fig.add_subplot(4,2,1)
plt.plot(i3.times(),i3.data,'c',label="Infra-RESCO")
plt.xlim(0,7201)
plt.xticks(fontsize=17)
plt.ylabel("Pa",fontsize=17)
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax2 = fig.add_subplot(4,2,2)
plt.plot(fi,ami,'c',label="Fmx=13.5 Hz")
plt.xlim(1,max(fi))
plt.xticks(fontsize=18)
#plt.xticks(np.arange(1,50,3))
#plt.ylim(0,0.000004)
plt.yticks(fontsize=15)
plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax3 = fig.add_subplot(4,2,3)
plt.plot(a3.times(),a3.data*1000,'r',label="RESCO")
plt.xlim(0,7201)
plt.xticks(fontsize=17)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.25,0.25)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax4 = fig.add_subplot(4,2,4)
plt.plot(f3,am3,'r',label="Fmx=26Hz")
plt.xlim(1,max(f3))
plt.xticks(fontsize=18)
plt.yticks(fontsize=15)
#plt.yticks(format='sci')
#plt.ylim(0,0.45E6)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax5 = fig.add_subplot(4,2,5)
plt.plot(b3.times(),b3.data*1000,'b',label="CGEO")
plt.xlim(0,7201)
plt.xticks(fontsize=17)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.25,0.25)
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax6 = fig.add_subplot(4,2,6)
plt.plot(fg,amg,'b',label="Fmx=22")
plt.xlim(1,max(fg))
plt.xticks(fontsize=18)
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax7 = fig.add_subplot(4,2,7)
plt.plot(c3.times(),c3.data*1000,'g',label="CUBE")
plt.xlim(0,7201)
plt.xticks(fontsize=17)
plt.xlabel("Time [s]",fontsize=17)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.25,0.25)
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax8 = fig.add_subplot(4,2,8)
plt.plot(fc,amc,'g',label="Fmx=45")
plt.axvline(x=50, linewidth=4,label="-50Hz")
plt.xlabel('Frequency [Hz]',fontsize=17)
plt.xticks(fontsize=18)
plt.xlim(1,max(fc))
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

plt.savefig("150718_e.png",format="PNG", dpi=300)

# %%
plt.rcParams['figure.figsize'] = 30, 25
fig = plt.figure()
plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.1)
plt.suptitle('28/07/18',fontsize=22)

ax1 = fig.add_subplot(4,2,1)
plt.plot(i5.times(),i5.data,'c',label="Infra-RESCO")
#plt.grid(True,linestyle='-')
plt.xlim(0,5400)
plt.xticks([])
plt.ylabel("mPa",fontsize=17)
plt.yticks(fontsize=18)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax2 = fig.add_subplot(4,2,2)
plt.plot(fi5,ami5,'c',label="Fmax=14,28")
plt.xlim(1,max(fi5))
plt.xticks([])
#plt.ylim(0,1.0E-4)
plt.yticks(fontsize=15)
plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax3 = fig.add_subplot(4,2,3)
plt.plot(a5.times(),a5.data*1000,'r',label="RESCO")
plt.xlim(0,5400)
plt.xticks([])
#plt.ylim(-20000,20000)
plt.ylabel("mm/s", fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.3,0.3)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax4 = fig.add_subplot(4,2,4)
plt.plot(f5,am5,'r',label="Fmax=12")
plt.xlim(1,max(f5))
plt.xticks([])
plt.yticks(fontsize=15)
plt.ylim(0,0.9E-12)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax5 = fig.add_subplot(4,2,5)
plt.plot(b5.times(),b5.data*1000,'b',label="CGEO")
plt.xlim(0,5400)
plt.xticks([])
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.3,0.3)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax6 = fig.add_subplot(4,2,6)
plt.plot(fg5,amg5,'b',label="Fmax=22")
plt.xlim(1,max(fg5))
plt.xticks([])
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax7 = fig.add_subplot(4,2,7)
plt.plot(c5.times(),c5.data*1000,'g',label="CUBE")
plt.xlim(0,5400)
plt.xticks(np.arange(0,5400,250),fontsize=18,rotation=90)
plt.xlabel("Tiempo [s]",fontsize=17)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.3,0.3)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax8 = fig.add_subplot(4,2,8)
plt.plot(fc5,amc5,'g',label="Fmax=25")
#plt.axvline(x=50, linewidth=4,label="50Hz")
plt.xlabel('Frecuencia [Hz]',fontsize=17)
plt.xticks(fontsize=18)
plt.xlim(1,max(fc5))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

#plt.savefig("280718l_.png",format="PNG")

# %%
plt.rcParams['figure.figsize'] = 15 , 10
fig = plt.figure()
#plt.subplots_adjust(hspace=0)
#plt.subplots_adjust(wspace=0.1)
plt.suptitle('28/07/18',fontsize=22)

plt.plot(c5.times(),c5.data*1000,'g',label="CUBE")
#plt.xlim(0,5400)
#plt.xticks(np.arange(0,5400,250),fontsize=18,rotation=90)
plt.xlabel("Tiempo [s]",fontsize=17)
plt.ylabel("mm/s",fontsize=15)
#plt.ylim(min(c5.data),max(c5.data))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

# %%
plt.rcParams['figure.figsize'] = 30, 25
fig = plt.figure()
plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.1)
plt.suptitle('16/08/18',fontsize=20)

ax1 = fig.add_subplot(4,2,1)
plt.plot(i7.times(),i7.data,'c',label="Infra-RESCO")
plt.xlim(0,10801)
plt.xticks([])
#plt.grid(True,linestyle='-')
plt.ylabel("Pa",fontsize=17)
plt.yticks(fontsize=18)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax2 = fig.add_subplot(4,2,2)
plt.plot(fi7,ami7,'c',label="Fmax=13")
plt.xlim(1,max(fi7))
plt.xticks([])
#plt.axvline(x=13, linewidth=4)
#plt.ylim(0,0.0000015)
plt.yticks(fontsize=15)
plt.ticklabel_format(style='sci',axis="y",scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax3 = fig.add_subplot(4,2,3)
plt.plot(a7.times(),a7.data*1000,'r',label="RESCO")
plt.xlim(0,10801)
plt.xticks([])
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.15,0.2)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax4 = fig.add_subplot(4,2,4)
plt.plot(f7,am7,'r',label="Fmax=23")
plt.xlim(1,max(f7))
plt.xticks([])
plt.ylim(0,2.5E-12)
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax5 = fig.add_subplot(4,2,5)
plt.plot(b7.times(),b7.data*1000,'b',label="CGEO")
plt.xlim(0,10801)
plt.xticks([])
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.15,0.2)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax6 = fig.add_subplot(4,2,6)
plt.plot(fg7,amg7,'b',label="Fmax=34.5")
plt.xlim(1,max(fg7))
plt.xticks([])
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax7 = fig.add_subplot(4,2,7)
plt.plot(c7.times(),c7.data*1000,'g',label="CUBE")
plt.xlim(0,10801)
plt.xlabel("Tiempo [s]",fontsize=17)
plt.xticks(np.arange(0,10801,500),fontsize=18,rotation=90)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.15,0.2)
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax8 = fig.add_subplot(4,2,8)
plt.plot(fc7,amc7,'g',label="Fmax=37")
plt.xlabel('Frecuencia [Hz]',fontsize=17)
plt.xticks(fontsize=18)
plt.xlim(1,max(fc7))
#plt.axvline(x=37, linewidth=4)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

#plt.savefig("160818l.png",format="PNG")

# %%
plt.rcParams['figure.figsize'] = 30, 25
fig = plt.figure()
plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.1)
plt.suptitle('17/08/18',fontsize=22)

ax1 = fig.add_subplot(4,2,1)
plt.plot(i8.times(),i8.data,'c',label="Infra-RESCO")
plt.xlim(0,7180.50)
plt.ylabel("mPa",fontsize=17)
plt.yticks(fontsize=18)
plt.axhline(445)
#plt.grid(True,linestyle='-')
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax2 = fig.add_subplot(4,2,2)
plt.plot(fi8,ami8,'c',label="Fmax=13.5")
plt.xlim(1,max(fi8))
plt.xticks([])
#plt.axvline(x=27, linewidth=4)
#plt.ylim(0,0.00006)
plt.yticks(fontsize=15)
plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax3 = fig.add_subplot(4,2,3)
plt.plot(a8.times(),a8.data*1000,'r',label="RESCO")
plt.xlim(0,7180.50)
plt.xticks([])
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.31,0.33)
#plt.axhline(13000)
plt.axhline(0.035)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax4 = fig.add_subplot(4,2,4)
plt.plot(f8,am8,'r',label="Fmax=15")
plt.xlim(1,max(f8))
plt.xticks([])
#plt.axvline(x=15, linewidth=4)
plt.ylim(0,0.5E-12)
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax5 = fig.add_subplot(4,2,5)
plt.plot(b8.times(),b8.data*1000,'b',label="CGEO")
plt.xlim(0,7180.50)
plt.xticks([])
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.31,0.33)
plt.axhline(0.32)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax6 = fig.add_subplot(4,2,6)
plt.plot(fg8,amg8,'b',label="Fmax=21.5")
plt.xlim(1,max(fg8))
plt.xticks([])
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax7 = fig.add_subplot(4,2,7)
plt.plot(c8.times(),c8.data*1000,'g',label="CUBE")
plt.xlim(0,7180.50)
plt.xticks(np.arange(0,7180.5,500),fontsize=18,rotation=90)
plt.xlabel("Tiempo [s]",fontsize=18)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.3,0.33)
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
#plt.axhline(5600000)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax8 = fig.add_subplot(4,2,8)
plt.plot(fc8,amc8,'g',label="Fmax=25.5")
#plt.axvline(x=50, linewidth=4,label="50Hz")
plt.xlabel('Frecuencia [Hz]',fontsize=17)
plt.xlim(1,max(fc8))
plt.xticks(fontsize=18)
#plt.axvline(x=25.5, linewidth=4)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)


#plt.savefig("170818l.png",format="PNG")
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f36b9fd5b70> (for post_execute):
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     148             try:
# --> 149                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     150             except OverflowError:
#
# OverflowError: In draw_path: Exceeded cell block limit
#
# During handling of the above exception, another exception occurred:
#
# OverflowError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
# ...

# %%
plt.rcParams['figure.figsize'] = 20, 10
fig = plt.figure()
plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.1)
plt.suptitle('17/08/18',fontsize=22)

plt.plot(c8.times(),c8.data*1000,'g',label="CUBE")
plt.xlim(0,7180.50)
plt.xticks(np.arange(0,7180.5,500),fontsize=18,rotation=90)
plt.xlabel("Tiempo [s]",fontsize=18)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=15)
plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
#plt.axhline(5600000)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

# %%
#plt.plot(fc8,amc8,'g',label="Fmax=25.5")
#plt.axvline(x=50, linewidth=4,label="50Hz")
#plt.xlabel('Frecuencia [Hz]',fontsize=17)
#plt.xlim(1,max(fc8))
#plt.axvline(x=25.5, linewidth=4)
#plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

# %%
max(c9.data)*1000
# Out:
# 0.19917860850747934

# %%
plt.rcParams['figure.figsize'] = 30, 25
fig = plt.figure()
plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.1)
plt.suptitle('18/08/18',fontsize=22)

ax1 = fig.add_subplot(4,2,1)
plt.plot(i9.times(),i9.data*1000,'c',label="Infra-RESCO")
plt.xlim(0,7201)
plt.xticks([])
plt.ylabel("mPa",fontsize=17)
plt.yticks(fontsize=18)
#plt.grid(True,linestyle='-')
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax2 = fig.add_subplot(4,2,2)
plt.plot(fi9,ami9,'c',label="Fmax=13.5,28.5")
plt.xlim(1,max(fi9))
plt.xticks([])
plt.ylim(0,0.00005)
plt.yticks(fontsize=15)
plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax3 = fig.add_subplot(4,2,3)
plt.plot(a9.times(),a9.data*1000,'r',label="RESCO")
plt.xlim(0,7201)
plt.xticks([])
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-1.7,2)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax4 = fig.add_subplot(4,2,4)
plt.plot(f9,am9,'r',label="Fmax=12.5")
plt.xlim(1,max(f9))
plt.xticks([])
plt.ylim(0,0.8E-10)
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax5 = fig.add_subplot(4,2,5)
plt.plot(b9.times(),b9.data*1000,'b',label="CGEO")
plt.xlim(0,7201)
plt.xticks([])
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-1.7,2)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax6 = fig.add_subplot(4,2,6)
plt.plot(fg9,amg9,'b',label="Fmax=12")
plt.xlim(1,max(fg9))
plt.xticks([])
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax7 = fig.add_subplot(4,2,7)
plt.plot(c9.times(),c9.data*1000,'g',label="CUBE")
plt.xlim(0,7201)
plt.xlabel("Tiempo [s]",fontsize=17)
plt.xticks(fontsize=18)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-1.7,2)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax8 = fig.add_subplot(4,2,8)
plt.plot(fc9,amc9,'g',label="Fmax=13.5")
#plt.axvline(x=50, linewidth=4,label="50Hz")
plt.xlabel('Frecuencia [Hz]',fontsize=17)
plt.xticks(fontsize=18)
plt.yticks(fontsize=15)
plt.xlim(1,max(fc9))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

#plt.savefig("180818l.png",format="PNG")

# %%
plt.rcParams['figure.figsize'] = 30, 25
fig = plt.figure()
plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.1)
plt.suptitle('22/08/18',fontsize=22)

ax1 = fig.add_subplot(4,2,1)
plt.plot(i10.times(),i10.data*1000,'c',label="Infra-RESCO")
plt.xlim(0,6001)
plt.ylabel("mPa",fontsize=17)
plt.yticks(fontsize=18)
#plt.grid(True,linestyle='-')
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax2 = fig.add_subplot(4,2,2)
plt.plot(fi10,ami10,'c',label="Fmax=13,28")
plt.xlim(1,max(fi10))
plt.xticks([])
plt.ylim(0,0.00002)
plt.yticks(fontsize=15)
plt.ticklabel_format(axis="y",style='sci',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax3 = fig.add_subplot(4,2,3)
plt.plot(a10.times(),a10.data*1000,'r',label="RESCO")
plt.xlim(0,6001)
plt.xticks([])
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-2.2,2.2)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax4 = fig.add_subplot(4,2,4)
plt.plot(f10,am10,'r',label="Fmax=12")
plt.xlim(1,max(f10))
plt.xticks([])
plt.yticks(fontsize=15)
#plt.ylim(0,2.5E6)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax5 = fig.add_subplot(4,2,5)
plt.plot(b10.times(),b10.data*1000,'b',label="CGEO")
plt.xlim(0,6001)
plt.xticks([])
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-2.2,2.2)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax6 = fig.add_subplot(4,2,6)
plt.plot(fg10,amg10,'b',label="Fmax=12")
plt.xlim(1,max(fg10))
plt.xticks([])
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax7 = fig.add_subplot(4,2,7)
plt.plot(c10.times(),c10.data*1000,'g',label="CUBE")
plt.xlim(0,6001)
plt.xlabel("Tiempo [s]",fontsize=17)
plt.xticks(fontsize=18)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-2.2,2.2)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax8 = fig.add_subplot(4,2,8)
plt.plot(fc10,amc10,'g',label="Fmax=13.5")
#plt.axvline(x=50, linewidth=4,label="50Hz")
plt.xlabel('Frecuencia [Hz]',fontsize=17)
plt.xticks(fontsize=18)
plt.xlim(1,max(fc10))
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

#plt.savefig("220818l.png",format="PNG")

# %%
plt.rcParams['figure.figsize'] = 20, 10
fig = plt.figure()
plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.1)
plt.suptitle('22/08/18',fontsize=22)


plt.plot(c10.times(),c10.data*1000,'g',label="CUBE")
plt.xlim(0,6001)
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

# %%
max(a11.data)*1000
# Out:
# 0.3971011442849018

# %%
plt.rcParams['figure.figsize'] = 30, 25
fig = plt.figure()
plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.1)
plt.suptitle('23/08/18',fontsize=22)

ax1 = fig.add_subplot(4,2,1)
plt.plot(i11.times(),i11.data*1000,'c',label="Infra-RESCO")
plt.xlim(0,7200)
plt.xticks([])
plt.ylabel("mPa",fontsize=17)
plt.yticks(fontsize=18)
#plt.grid(True,linestyle='-')
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax2 = fig.add_subplot(4,2,2)
plt.plot(fi11,ami11,'c',label="Fmax=13,26.5")
plt.xlim(1,max(fi11))
plt.xticks([])
plt.ylim(0,0.0001)
plt.yticks(fontsize=15)
plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax3 = fig.add_subplot(4,2,3)
plt.plot(a11.times(),a11.data*100,'r',label="RESCO")
plt.xlim(0,7200)
plt.xticks([])
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-2.5,2.5)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax4 = fig.add_subplot(4,2,4)
plt.plot(f11,am11,'r',label="Fmax=10.5")
plt.xlim(1,max(f11))
plt.xticks([])
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax5 = fig.add_subplot(4,2,5)
plt.plot(b11.times(),b11.data*1000,'b',label="CGEO")
plt.xlim(0,7200)
plt.xticks([])
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-2.5,2.5)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax6 = fig.add_subplot(4,2,6)
plt.plot(fg11,amg11,'b',label="Fmax=12")
plt.xlim(1,max(fg11))
plt.xticks([])
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax7 = fig.add_subplot(4,2,7)
plt.plot(c11.times(),c11.data*1000,'g',label="CUBE")
plt.xlim(0,7200)
plt.xticks(fontsize=18)
plt.xlabel("Tiempo[s]")
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-2.5,2.5)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax8 = fig.add_subplot(4,2,8)
plt.plot(fc11,amc11,'g',label="Fmax=13")
#plt.axvline(x=50, linewidth=4,label="50Hz")
plt.xlabel('Frecuencia [Hz]',fontsize=17)
plt.xticks(fontsize=18)
plt.xlim(1,max(fc11))
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

#plt.savefig("230818l.png",format="PNG")

# %%
plt.rcParams['figure.figsize'] = 20, 10
fig = plt.figure()
plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.1)
plt.suptitle('23/08/18',fontsize=22)

plt.plot(c11.times(),c11.data*1000,'g',label="CUBE")
plt.xlim(0,7200)
plt.ylabel("?",fontsize=17)
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

# %%
max(c17.data)*1000
# Out:
# 0.190025972960439

# %%
plt.rcParams['figure.figsize'] = 30, 25
fig = plt.figure()
plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.08)
plt.suptitle('06/10/18',fontsize=22)

ax1 = fig.add_subplot(4,2,1)
plt.plot(i17.times(),i17.data*1000,'c',label="Infra-RESCO")
plt.xlim(0,7201)
plt.xticks([])
plt.ylabel("mPa",fontsize=17)
plt.yticks(fontsize=18)
#plt.grid(True,linestyle='-')
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax2 = fig.add_subplot(4,2,2)
plt.plot(fi17,ami17,'c',label="Fmax=13,28")
plt.xlim(1,max(fi17))
plt.xticks([])
plt.ylim(0,0.000006)
plt.yticks(fontsize=15)
plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax3 = fig.add_subplot(4,2,3)
plt.plot(a17.times(),a17.data*1000,'r',label="RESCO")
plt.xlim(0,7201)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.7,0.7)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax4 = fig.add_subplot(4,2,4)
plt.plot(f17,am17,'r',label="Fmax=11")
plt.xlim(1,max(f17))
plt.xticks([])
plt.yticks(fontsize=15)
#plt.ylim(0,400000)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax5 = fig.add_subplot(4,2,5)
plt.plot(b17.times(),b17.data*1000,'b',label="CGEO")
plt.xlim(0,7201)
plt.xticks([])
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
plt.ylim(-0.7,0.7)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax6 = fig.add_subplot(4,2,6)
plt.plot(fg17,amg17,'b',label="Fmax=16.5")
plt.xlim(1,max(fg17))
plt.xticks([])
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax7 = fig.add_subplot(4,2,7)
plt.plot(c17.times(),c17.data*1000,'g',label="CUBE")
plt.xlim(0,7201)
plt.xticks(fontsize=17)
plt.xlabel("Time [s]", fontsize=17)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
#plt.axhline(10000000)
plt.ylim(-0.7,0.7)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax8 = fig.add_subplot(4,2,8)
plt.plot(fc17,amc17,'g',label="Fmax=13.5")
plt.xlabel('Frequency [Hz]',fontsize=17)
plt.xticks(fontsize=18)
plt.xlim(1,max(fc17))
plt.yticks(fontsize=15)
#plt.axvline(x=13.5, linewidth=1)
#plt.axvline(x=42, linewidth=4)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

plt.savefig("0610718l_e.png",format="PNG",dpi=350)

# %%
plt.rcParams['figure.figsize'] = 20, 10
fig = plt.figure()
plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.1)
plt.suptitle('06/10/18',fontsize=22)

plt.plot(c17.times(),c17.data,'g',label="CUBE")
plt.xlim(0,7201)
plt.ylabel("?",fontsize=17)
plt.yticks(fontsize=15)
#plt.axhline(10000000)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

# %%
r20
# Out:
# 4 Trace(s) in Stream:
# UC.MNGR..BDF | 2018-10-19T22:30:00.000000Z - 2018-10-20T01:00:00.000000Z | 100.0 Hz, 900001 samples
# UC.MNGR..HHE | 2018-10-19T22:30:00.000000Z - 2018-10-20T01:00:00.000000Z | 100.0 Hz, 900001 samples
# UC.MNGR..HHN | 2018-10-19T22:30:00.000000Z - 2018-10-20T01:00:00.000000Z | 100.0 Hz, 900001 samples
# UC.MNGR..HHZ | 2018-10-19T22:30:00.000000Z - 2018-10-20T01:00:00.000000Z | 100.0 Hz, 900001 samples

# %%
plt.rcParams['figure.figsize'] = 30, 25
fig = plt.figure()
plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.08)
plt.suptitle('19/10/18',fontsize=22)

ax1 = fig.add_subplot(4,2,1)
plt.plot(i20.times(),i20.data*1000,'c',label="Infra-RESCO")
plt.xlim(0,9001)
plt.xticks([])
plt.ylabel("mPa",fontsize=17)
plt.yticks(fontsize=18)
#plt.grid(True,linestyle='-')
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax2 = fig.add_subplot(4,2,2)
plt.plot(fi20,ami20,'c',label="Fmax=")
plt.xlim(1,max(fi20))
plt.xticks([])
plt.ylim(0,0.00003)
plt.yticks(fontsize=15)
plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax3 = fig.add_subplot(4,2,3)
plt.plot(a20.times(),a20.data*1000,'r',label="RESCO")
plt.xlim(0,9001)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
#plt.ylim(-0.7,0.7)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax4 = fig.add_subplot(4,2,4)
plt.plot(f20,am20,'r',label="Fmax=")
plt.xlim(1,max(f20))
plt.xticks([])
plt.yticks(fontsize=15)
#plt.ylim(0,400000)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax5 = fig.add_subplot(4,2,5)
plt.plot(b20.times(),b20.data*1000,'b',label="CGEO")
plt.xlim(0,9001)
plt.xticks([])
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
#plt.ylim(-0.7,0.7)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax6 = fig.add_subplot(4,2,6)
plt.plot(fg20,amg20,'b',label="Fmax=")
plt.xlim(1,max(fg20))
plt.xticks([])
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax7 = fig.add_subplot(4,2,7)
plt.plot(c20.times(),c20.data*1000,'g',label="CUBE")
plt.xlim(0,9001)
plt.xticks(fontsize=17)
plt.xlabel("Time [s]", fontsize=17)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
#plt.axhline(10000000)
#plt.ylim(-0.7,0.7)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax8 = fig.add_subplot(4,2,8)
plt.plot(fc20,amc20,'g',label="Fmax=")
plt.xlabel('Frequency [Hz]',fontsize=17)
plt.xticks(fontsize=18)
plt.xlim(1,max(fc20))
plt.yticks(fontsize=15)
plt.axvline(x=14, linewidth=1)
#plt.axvline(x=42, linewidth=4)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

#plt.savefig("0610718l_e.png",format="PNG",dpi=350)

# %%
plt.rcParams['figure.figsize'] = 30, 25
fig = plt.figure()
plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.08)
plt.suptitle('28/10/18',fontsize=22)

ax1 = fig.add_subplot(4,2,1)
plt.plot(i21.times(),i21.data*1000,'c',label="Infra-RESCO")
plt.xlim(0,4501)
plt.xticks([])
plt.ylabel("mPa",fontsize=17)
plt.yticks(fontsize=18)
#plt.grid(True,linestyle='-')
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax2 = fig.add_subplot(4,2,2)
plt.plot(fi21,ami21,'c',label="Fmax=13,28")
plt.xlim(1,max(fi21))
plt.xticks([])
plt.ylim(0,1.0E-5)
plt.yticks(fontsize=15)
plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax3 = fig.add_subplot(4,2,3)
plt.plot(a21.times(),a21.data*1000,'r',label="RESCO")
plt.xlim(0,4501)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
#plt.ylim(-0.7,0.7)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax4 = fig.add_subplot(4,2,4)
plt.plot(f21,am21,'r',label="Fmax=")
plt.xlim(1,max(f21))
plt.xticks([])
plt.yticks(fontsize=15)
plt.ylim(0,0.11E-10)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax5 = fig.add_subplot(4,2,5)
plt.plot(b21.times(),b21.data*1000,'b',label="CGEO")
plt.xlim(0,4501)
plt.xticks([])
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
#plt.ylim(-0.7,0.7)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax6 = fig.add_subplot(4,2,6)
plt.plot(fg21,amg21,'b',label="Fmax=")
plt.xlim(1,max(fg21))
plt.xticks([])
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax7 = fig.add_subplot(4,2,7)
plt.plot(c21.times(),c21.data*1000,'g',label="CUBE")
plt.xlim(0,4501)
plt.xticks(fontsize=17)
plt.xlabel("Time [s]", fontsize=17)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
#plt.axhline(10000000)
#plt.ylim(-0.7,0.7)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax8 = fig.add_subplot(4,2,8)
plt.plot(fc21,amc21,'g',label="Fmax=13.5")
plt.xlabel('Frequency [Hz]',fontsize=17)
plt.xticks(fontsize=18)
plt.xlim(1,max(fc21))
plt.yticks(fontsize=15)
#plt.axvline(x=13.5, linewidth=1)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

#plt.savefig("0610718l_e.png",format="PNG",dpi=350)

# %%
plt.rcParams['figure.figsize'] = 20, 10
fig = plt.figure()
plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.1)
plt.suptitle('09/07/18',fontsize=22)

ax1 = fig.add_subplot(4,2,1)
plt.plot(i.times(),i.data*1000,'c',label="Infra-RESCO")
#plt.xlim(0,7201)
plt.ylabel("mPa",fontsize=17)
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax2 = fig.add_subplot(4,2,2)
plt.plot(fi2,ami2,'c',label="Fmx= Hz")
plt.xlim(1,max(fi2))
plt.xlabel('Frecuencia [Hz]',fontsize=17)
plt.xticks(fontsize=18)
#plt.xticks(np.arange(1,50,3))
plt.ylim(0,0.00008)
plt.yticks(fontsize=15)
plt.axvline(x=14, linewidth=2)
plt.axvline(x=27, linewidth=2)
plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax3 = fig.add_subplot(4,2,3)
plt.plot(z.times(),z.data*1000,'r',label="RESCO")
plt.xlim(0,7201)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
#plt.ylim(-0.25,0.25)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax4 = fig.add_subplot(4,2,4)
plt.plot(f2,am2,'r',label="Fmx=Hz")
plt.xlim(1,max(f2))
plt.xlabel('Frecuencia [Hz]',fontsize=17)
plt.xticks(fontsize=18)
#plt.axvline(x=10.5, linewidth=2)
#plt.yticks(format='sci')
#plt.ylim(0,0.45E6)


plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

# %%
r19 = read("UC_MNGR_2018101722.mseed")

# %%
r19.remove_sensitivity(inv_r)
# Out:
# 4 Trace(s) in Stream:
# UC.MNGR..HHZ | 2018-10-17T22:15:00.000000Z - 2018-10-17T23:15:00.000000Z | 100.0 Hz, 360001 samples
# UC.MNGR..HHN | 2018-10-17T22:15:00.000000Z - 2018-10-17T23:15:00.000000Z | 100.0 Hz, 360001 samples
# UC.MNGR..HHE | 2018-10-17T22:15:00.000000Z - 2018-10-17T23:15:00.000000Z | 100.0 Hz, 360001 samples
# UC.MNGR..BDF | 2018-10-17T22:15:00.000000Z - 2018-10-17T23:15:00.000000Z | 100.0 Hz, 360001 samples

# %%
z19 = r19[0]

# %%
i19 = r19[3]

# %%
plt.rcParams['figure.figsize'] = 20, 10
fig = plt.figure()
plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0.1)
plt.suptitle('17/10/18',fontsize=22)

ax1 = fig.add_subplot(4,2,1)
plt.plot(i19.times(),i19.data*1000,'c',label="Infra-RESCO")
#plt.xlim(0,7201)
plt.ylabel("mPa",fontsize=17)
plt.yticks(fontsize=15)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax2 = fig.add_subplot(4,2,2)
plt.plot(fi19,ami19,'c',label="Fmx= Hz")
plt.xlim(1,max(fi19))
plt.xlabel('Frecuencia [Hz]',fontsize=17)
plt.xticks(fontsize=18)
#plt.xticks(np.arange(1,50,3))
plt.ylim(0,0.3E-4)
plt.yticks(fontsize=15)
plt.axvline(x=14, linewidth=2)
plt.axvline(x=27, linewidth=2)
plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax3 = fig.add_subplot(4,2,3)
plt.plot(z19.times(),z19.data*1000,'r',label="RESCO")
#plt.xlim(0,7201)
plt.ylabel("mm/s",fontsize=17)
plt.yticks(fontsize=18)
#plt.ylim(-0.25,0.25)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

ax4 = fig.add_subplot(4,2,4)
plt.plot(f19,am19,'r',label="Fmx=Hz")
plt.xlim(1,max(f19))
plt.xlabel('Frecuencia [Hz]',fontsize=17)
plt.xticks(fontsize=18)
#plt.axvline(x=10.5, linewidth=2)
#plt.yticks(format='sci')
plt.ylim(0,0.3E-12)
plt.legend(loc='upper right',handlelength=0, handletextpad=0,fontsize=18)

# %%
#plt.figure(figsize=(30,25))

#plt.subplots_adjust(hspace=0)

#plt.subplot(311)
#plt.title("28/07/18 L5",fontsize=25)
#plt.plot(a5,'r',label="RESCO")
#plt.yticks(fontsize=15)
#legend(loc="best",fontsize=20)

#plt.subplot(312)
#plt.plot(b5,'b',label="CGEO")
#plt.yticks(fontsize=15)
#legend(loc="best",fontsize=20)

#plt.subplot(313)
#plt.plot(c5,'g',label="CUBE")
#plt.yticks(fontsize=15)
#legend(loc="best",fontsize=20)
#plt.xticks(fontsize=20)

# %%
#plt.figure(figsize=(30,25))

#plt.subplots_adjust(hspace=0)

#plt.subplot(311)
#plt.title("16/08/18 L7",fontsize=25)
#plt.plot(a7,'r',label="RESCO")
#plt.yticks(fontsize=15)
#legend(loc="best",fontsize=20)

#plt.subplot(312)
#plt.plot(b7,'b',label="CGEO")
#plt.yticks(fontsize=15)
#legend(loc="best",fontsize=20)

#plt.subplot(313)
#plt.plot(c7,'g',label="CUBE")
#plt.yticks(fontsize=15)
#legend(loc="best",fontsize=20)
#plt.xticks(fontsize=20)

# %%
#stream.plot(equal_scale=False)

# %%
plt.rcParams['figure.figsize'] = 25, 20
fig = plt.figure()
plt.suptitle('15/07/18',fontsize=18)

ax1 = fig.add_subplot(4,2,1)
plt.plot(a3,'r',label="RESCO")
plt.xlim(0,720001)
plt.legend(loc='upper right')

ax2 = fig.add_subplot(4,2,2)
plt.plot(f3,am3,'r',label="Fmax=")
plt.xlim(1,max(f3))
plt.xlabel('Frecuencia')
plt.ylim(0,0.45E6)
plt.legend(loc='upper right')

ax3 = fig.add_subplot(4,2,3)
plt.plot(b3,'b',label="CGEO")
plt.xlim(0,720001)
plt.legend(loc='upper right')

ax4 = fig.add_subplot(4,2,4)
plt.plot(fg,amg,'b',label="Fmax=")
plt.xlim(1,max(fg))
plt.xlabel('Frecuencia')
plt.legend(loc='upper right')

ax5 = fig.add_subplot(4,2,5)
plt.plot(c3,'g',label="CUBE")
plt.xlim(0,1440001)
plt.legend(loc='upper right')

ax6 = fig.add_subplot(4,2,6)
plt.plot(fc,amc,'g',label="Fmax=")
#plt.xlim(1,50)
plt.xlabel('Frecuencia')
plt.legend(loc='upper right')

ax7 = fig.add_subplot(4,2,7)
plt.plot(i3,'c',label="Infra-RESCO")
plt.xlim(0,720001)
plt.legend(loc='upper right')

ax8 = fig.add_subplot(4,2,8)
plt.plot(fi,ami,'c',label="Fmax=")
plt.xlim(1,max(fi))
plt.xlabel('Frecuencia')
plt.ylim(0,0.65E6)
plt.legend(loc='upper right')

#plt.subplots_adjust(wspace=0.3, hspace=0.4)

# %%
plt.figure(figsize(50,50))
fig, axs = plt.subplots(4,2)
plt.suptitle('15/07/2018',fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

axs[0,0].plot(a3,'r',label="RESCO")
axs[0,0].legend(loc='upper right',fontsize=18)
axs[0,0].set_xlabel('Tiempo[s]',fontsize=18)
axs[0,0].set_xlim(0,720001)
axs[0,0].tick_params(labelsize='medium')


axs[0,1].plot(fr,am,'r')
axs[0,1].set_xlabel('Frecuencia [Hz]',fontsize=18)
axs[0,1].set_xlim(1,max(fr))
axs[0,1].set_ylim(0,0.35E7)

axs[1,0].plot(b3,'b',label="CGEO")
axs[1,0].legend(loc='upper right',fontsize=18)
axs[1,0].set_xlabel('Tiempo[s]',fontsize=18)
axs[1,0].set_xlim(0,720001)


axs[1,1].plot(frg,amg,'b')
axs[1,1].set_xlabel('Frecuencia [Hz]',fontsize=18)
axs[1,1].set_xlim(1,max(frg))

axs[2,0].plot(c3,'g',label="CUBE")
axs[2,0].legend(loc='upper right',fontsize=18)
axs[2,0].set_xlabel('Tiempo[s]',fontsize=18)
axs[2,0].set_xlim(0,1440001)

axs[2,1].plot(frc,amc,'g')
axs[2,1].set_xlabel('Frecuencia [Hz]',fontsize=18)
axs[2,1].set_xlim(1,max(frc))

axs[3,0].plot(i3,'c',label="Infra-RESCO")
axs[3,0].legend(loc='upper right',fontsize=18)
axs[3,0].set_xlabel('Tiempo[s]',fontsize=18)
axs[3,0].set_xlim(0,720001)

axs[3,1].plot(fri,ami,'c')
axs[3,1].set_xlabel('Frecuencia [Hz]',fontsize=18)
axs[3,1].set_xlim(1,max(fri))
axs[3,1].set_ylim(0,0.4E7)

#plt.savefig("l1507.png")

# %%
#fr, am = signal.periodogram(a3,fs=100,detrend='constant'); otro método

# %%
#r4 = read("UC_MNGR_2018072513.mseed");
#cg4 = read("AM.R9C82.2018072513.mseed");
#cu4 = read("UC.MNG2.EHZ-2018072513.mseed");
#a4 = r4[0];
#b4 = cg4[0];
#c4 = cu4[0];
#i4 = r4[3];
#a4.detrend();
#b4.detrend();
#c4.detrend();
#i4.detrend();

#y el 6 tampoco es un lahar.

# %%
#f, a = signal.welch(a3,fs=100,noverlap=None)
